# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
import seaborn as sns
from imblearn.over_sampling import SMOTE

# %%
def remove_outliers_iqr(df):
    # Define a function to calculate IQR
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1
    df_out = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
    return df_out


def plot_corr_matrix(df):
    # Plot correlation matrix
    corr = df.corr()
    mask = np.triu(np.ones_like(corr, dtype=bool))
    plt.figure(figsize=(12, 8))
    sns.heatmap(corr, mask=mask, annot=True, cbar=False, cmap="coolwarm")
    plt.show()


def plot_stroke_pie(df):
    # Visualize the ratio of 'stroke'
    df["stroke"].value_counts().plot(kind="pie", autopct="%1.1f%%")
    plt.show()


def plot_dist(df):
    # Plot histograms for numerical columns
    num_features = df.select_dtypes(include=["int64", "float64"]).columns
    for feature in num_features:
        plt.figure(figsize=(6, 4))
        sns.histplot(df[feature], kde=True)
        plt.title(f"Histogram for {feature}")
        plt.show()

    # Plot bar plots for categorical columns
    cat_features = df.select_dtypes(include=["object", "category"]).columns
    for feature in cat_features:
        plt.figure(figsize=(6, 4))
        sns.countplot(x=df[feature])
        plt.title(f"Bar plot for {feature}")
        plt.show()

# %%
# Load the data
path = 'healthcare-dataset-stroke-data-raw.csv'
df = pd.read_csv(path)

# %%
print(df.shape)
df.head()
# Out:
# (5110, 12)
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
# Drop the 'id' column
df = df.drop("id", axis=1)

# %%
# Convert to categorical
df["stroke"] = df["stroke"].astype("category")
df["hypertension"] = df["hypertension"].astype("category")
df["heart_disease"] = df["heart_disease"].astype("category")

# %%
# plot_corr_matrix(df)
plot_dist(df)

# %%
plot_stroke_pie(df)

# %%
# Handle missing values for numerical features (fill with median)
num_features = df.select_dtypes(include=["int64", "float64"]).columns
imputer = SimpleImputer(strategy="median")
df[num_features] = imputer.fit_transform(df[num_features])

# Handle missing values for categorical features (fill with mode)
cat_features = df.select_dtypes(include=["object", "category"]).columns
imputer = SimpleImputer(strategy="most_frequent")
df[cat_features] = imputer.fit_transform(df[cat_features])

# %%
# Remove rows where 'bmi' is larger than 75
df = df[df["bmi"] <= 80]
# Convert 'Other' gender to 'Female'
df["gender"] = df["gender"].replace("Other", "Female")
print(df.shape)
# Out:
# (5108, 11)

# %%
plot_dist(df)

# %%
# Apply StandardScaler to numerical features
# scaler = StandardScaler()
# df[num_features] = scaler.fit_transform(df[num_features])

# Apply LabelEncoder to categorical features
encoder = LabelEncoder()
for column in cat_features:
    df[column] = encoder.fit_transform(df[column])

# %%
plot_corr_matrix(df)

# %%
# statistics
df.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  5108.000000  5108.000000   5108.000000    5108.000000   5108.000000
# mean      0.413665    43.232772      0.097103       0.054033      0.656226
# std       0.492538    22.613977      0.296126       0.226105      0.475013
# min       0.000000     0.080000      0.000000       0.000000      0.000000
# 25%       0.000000    25.000000      0.000000       0.000000      0.000000
# 50%       0.000000    45.000000      0.000000       0.000000      1.000000
# 75%       1.000000    61.000000      0.000000       0.000000      1.000000
# max       1.000000    82.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  5108.000000     5108.000000        5108.000000  5108.000000
# mean      2.167776        0.508222         106.166026    28.836218
# std       1.090502        0.499981          45.282903     7.589470
# min       0.000000        0.000000          55.120000    10.300000
# 25%       2.000000        0.000000          77.275000    23.800000
# 50%       2.000000        1.000000          91.890000    28.100000
# 75%       3.000000        1.000000         114.107500    32.800000
# max       4.000000        1.000000         271.740000    78.000000
#
#        smoking_status       stroke
# count     5108.000000  5108.000000
# mean         1.377056     0.048747
# std          1.071535     0.215360
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          2.000000     0.000000
# 75%          2.000000     0.000000
# max          3.000000     1.000000

# %%
from sklearn.model_selection import train_test_split

# Split the dataset
X = df.drop("stroke", axis=1)
y = df["stroke"]
x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")

# Apply SMOTE to the training set
smote = SMOTE(sampling_strategy=0.6, random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# Print the shapes of the resulting datasets
print(f"x_train_smote shape: {x_train_smote.shape}")
print(f"y_train_smote shape: {y_train_smote.shape}")
# Out:
# x_test shape: (1022, 10)
# y_test shape: (1022,)
# x_train_smote shape: (6219, 10)
# y_train_smote shape: (6219,)

# %%
# Merge X_smote_df and y_smote_df
df_smote = pd.concat([x_train_smote, y_train_smote], axis=1)

# %%
print(df_smote.shape)
plot_stroke_pie(df_smote)
# Out:
# (6219, 11)

# %%
plot_corr_matrix(df_smote)

# %%
plot_dist(df_smote)

# %%
# Save df_smote as a CSV file
df_smote.to_csv("healthcare-dataset-stroke-prep-train.csv", index=False)

# %%
df_smote_test = pd.concat([x_test, y_test], axis=1)
df_smote_test.to_csv("healthcare-dataset-stroke-prep-test.csv", index=False)
